# %%
import pandas as pd
import os

# %%
IOC = "./ComponmentLibrary.xlsx"
#SHEETNAMEC = "21002smdelectrolyticcapacitor"
SHEETNAMEC = "20001pieceresistor"
componment = pd.read_excel(io=IOC, sheetname=SHEETNAMEC)
componment.head(1)
# Out:
#     partnumber    a                   description            b    c  d    e  \
# 0  20001-00003  RES  片状电阻;1/10W-100R±1%-0603;RoHS  100Ω±F-0603  100  `  ±1%
#
#          f       g                                                  h
# 0  A(优先选用)  353939  http://pdm.invt.com.cn/Windchill/servlet/TypeB...

# %%
#IOD = "./destination.xlsx"
#dest  = pd.read_excel(io = IOD)
dest = pd.DataFrame()
#row = pd.DataFrame(['python', 'pandas', 10], ['name','lib','rank'])
#dest.append(row,ignore_index=True)

# %%
#os.remove(r'H:\Deep learning\BomAutoProcess\destination.xlsx')
IOS = "./source.xlsx"
SHEETNAME_S = "Sheet1"
PART_SIZE_S = "1206"

#select_voltage = "25V"
df = pd.read_excel(io=IOS, sheetname=SHEETNAME_S)
dest = pd.DataFrame()
dest_row = 0
#for i in df["specification"]:
if 1:
   # slice_part = i.split(" ")[0]
   # print slice_part
    slice_part = "K"
   # print "==================="
    componment_row = 0
    for alic in componment["description"]:
        
        #if ("-"+slice_part in alic) or (";"+slice_part in alic):
        if (slice_part in alic) or (slice_part in alic):
                if (PART_SIZE_S in alic):# and (select_voltage in alic):
                   
                    #componment[componment_row:componment_row+1].to_excel('./destination.xlsx')
                    #dest.iloc[dest_row] = componment[componment_row:componment_row+1]
                    dest = dest.append(componment[componment_row:componment_row+1], ignore_index=True)
                    #print  componment[componment_row:componment_row+1]
                    dest_row += 1
        componment_row += 1

dest.to_excel('./destination.xlsx')
dest
# Out:
#      partnumber    a                        description                   b  \
# 0   20001-00205  RES      片状电阻;1/4W;5.1KR;±5%;1206;RoHS        5.1KΩ±J-1206
# 1   20001-00441  RES       片状电阻;1/4W;680KR±5%;1206;RoHS                 NaN
# 2   20001-00452  RES       片状电阻;1/4W;560KR±5%;1206;RoHS                 NaN
# 3   20001-00767  RES      片状电阻;1/4W;160KR;±1%;1206;RoHS    RC1206FR-07160KL
# 4   20001-00837  RES    片状电阻;1/4W;1KR;±1%;1206;RoHS;汽车级      AC1206FR-071KL
# 5   20001-00772  RES      片状电阻;1/4W;390KR;±1%;1206;RoHS    RC1206FR-07390KL
# 6   20001-00320  RES       片状电阻;1/4W-1.5KR±5%-1206;RoHS        1.5KΩ±J-1206
# 7   20001-00520  RES       片状电阻;1/4W;5.6KR±1%;1206;RoHS                 NaN
# 8   20001-00553  RES       片状电阻;1/4W;180KR±1%;1206;RoHS                 NaN
# 9   20001-00467  RES      片状电阻;1/4W;27.4KR±1%;1206;RoHS                 NaN
# 10  20001-00710  RES        片状电阻;1/4W;2KR;±1%;1206;RoHS      RC1206FR-072KL
# 11  20001-00923  RES  片状电阻;1/4W;510KR;±1%;1206;汽车级;RoHS    AC1206FR-07510KL
# 12  20001-00864  RES  片状电阻;1/4W;110KR;±1%;1206;汽车级;RoHS    AC1206FR-07110KL
# 13  20001-00940  RES       片状电阻;1/4W;82KR;±1%;1206;RoHS     RC1206FR-0782KL
# 14  20001-00948  RES   片状电阻;1/4W;33KR;±1%;1206;汽车级;RoHS     AC1206FR-0733KL
# 15  20001-00289  RES       片状电阻;1/4W-200KR±1%-1206;RoHS    RC1206FR-07200KL
# 16  20001-00294  RES        片状电阻;1/4W-499K±1%-1206;RoHS    RC1206FR-07499KL
# 17  20001-00295  RES        片状电阻;1/4W-68KR±1%-1206;RoHS     RC1206FR-0768KL
# 18  20001-00508  RES       片状电阻;1/4W;3.6KR±1%;1206;RoHS                 NaN
# 19  20001-00523  RES       片状电阻;1/4W;2.7KR±1%;1206;RoHS                 NaN
# 20  20001-00447  RES       片状电阻;1/4W;15KR;±1%;1206;RoHS     RC1206JR-0715KL
# 21  20001-00716  RES        片状电阻;1/4W;1KR;±1%;1206;RoHS      RC1206FR-071KL
# 22  20001-00768  RES      片状电阻;1/4W;430KR;±1%;1206;RoHS    RC1206FR-07430KL
# 23  20001-00941  RES      片状电阻;1/4W;330KR;±1%;1206;RoHS    RC1206FR-07330KL
# 24  20001-00287  RES       片状电阻;1/4W-100KR±1%-1206;RoHS    RC1206FR-07100KL
# 25  20001-00572  RES        片状电阻;1/4W;36KR;1%;1206;RoHS     RC1206FR-0736KL
# 26  20001-00557  RES       片状电阻;1/4W;22KR;±1%;1206;RoHS     RC1206FR-0722KL
# 27  20001-00444  RES      片状电阻;1/4W;1.2KR;±1%;1206;RoHS     RC1206FR-071K2L
# 28  20001-00455  RES         片状电阻;1/4W;1KR±1%;1206;RoHS                 NaN
# 29  20001-00761  RES      片状电阻;1/4W;240KR;±1%;1206;RoHS    RC1206FR-07240KL
# ..          ...  ...                                ...                 ...
# 45  20001-00855  RES  片状电阻;1/4W;330KR;±1%;1206;汽车级;RoHS    AC1206FR-07330KL
# 46  20001-00939  RES      片状电阻;1/4W;110KR;±1%;1206;RoHS    RC1206FR-07110KL
# 47  20001-00351  RES      片状电阻;1/4W;5.1KR;±1%;1206;RoHS  1/4W-5.1kΩ±1%-1206
# 48  20001-00318  RES        片状电阻;1/4W-301K±1%-1206;RoHS    RC1206FR-07301KL
# 49  20001-00206  RES       片状电阻;1/4W-510KR±5％-1206;RoHS        510KΩ±J-1206
# 50  20001-00213  RES        片状电阻;1/4W;2KR;±1%;1206;RoHS    1/4W-2kΩ±1%-1206
# 51  20001-00405  RES       片状电阻;1/4W;6.8KR±5%;1206;RoHS                 NaN
# 52  20001-00462  RES        片状电阻;1/4W;18KR±1%;1206;RoHS                 NaN
# 53  20001-00494  RES       片状电阻;1/4W;47KR;±1%;1206;RoHS                 NaN
# 54  20001-00764  RES       片状电阻;1/4W;33KR;±1%;1206;RoHS     RC1206FR-0733KL
# 55  20001-00886  RES   片状电阻;1/4W;22KR;±5%;1206;汽车级;RoHS     AC1206JR-0722KL
# 56  20001-00915  RES  片状电阻;1/4W;274KR;±1%;1206;汽车级;RoHS    AC1206FR-07274KL
# 57  20001-00321  RES        片状电阻;1/4W-22KR±5％-1206;RoHS         22KΩ±J-1206
# 58  20001-00196  RES       片状电阻;1/4W-2.4KR±5％-1206;RoHS        2.4KΩ±J-1206
# 59  20001-00201  RES      片状电阻;1/4W;3.3KR;±5%;1206;RoHS        3.3KΩ±J-1206
# 60  20001-00527  RES   片状电阻;1/4W;51KR±0.1%;1206;薄膜;RoHS                 NaN
# 61  20001-00765  RES       片状电阻;1/4W;43KR;±1%;1206;RoHS     RC1206FR-0743KL
# 62  20001-00775  RES      片状电阻;1/4W;120KR;±1%;1206;RoHS    RC1206FR-07120KL
# 63  20001-00777  RES      片状电阻;1/4W;365KR;±1%;1206;RoHS    RC1206FR-07365KL
# 64  20001-00894  RES   片状电阻;1/4W;33KR;±5%;1206;汽车级;RoHS     AC1206JR-0733KL
# 65  20001-00847  RES   片状电阻;1/4W;75KR;±1%;1206;RoHS;汽车级     AC1206FR-0775KL
# 66  20001-00866  RES  片状电阻;1/4W;100KR;±1%;1206;RoHS;汽车级    AC1206FR-07100KL
# 67  20001-00288  RES       片状电阻;1/4W;20KR;±1%;1206;RoHS     RC1206FR-0720KL
# 68  20001-00217  RES      片状电阻;1/4W;510KR;±1%;1206;RoHS        510KΩ±F-1206
# 69  20001-00550  RES   片状电阻;1/4W;27KR±0.1%;1206;薄膜;RoHS                 NaN
# 70  20001-00422  RES       片状电阻;1/4W;4.7KR±1%;1206;RoHS                 NaN
# 71  20001-00451  RES       片状电阻;1/4W;2.2KR±1%;1206;RoHS                 NaN
# 72  20001-00766  RES      片状电阻;1/4W;220KR;±1%;1206;RoHS    RC1206FR-07220KL
# 73  20001-00916  RES  片状电阻;1/4W;6.8KR;±1%;1206;汽车级;RoHS     AC1206FR-076K8L
# 74  20001-00848  RES   片状电阻;1/4W;82KR;±1%;1206;汽车级;RoHS     AC1206FR-0782KL
#
#          c      d      e        f       g  \
# 0    5.1kΩ   1/4W    ±5%  B(推荐选用)   81535
# 1    680KΩ   1/4W    ±5%  B(推荐选用)       0
# 2    560KΩ   1/4W    ±5%  B(推荐选用)       0
# 3    160kΩ   1/4W    ±1%  C(可以选用)  224400
# 4      1kΩ   1/4W    ±1%  C(可以选用)    9000
# 5    390kΩ   1/4W    ±1%  C(可以选用)  234400
# 6     1.5k  43104    ±5%  B(推荐选用)   14560
# 7    5.6KΩ   1/4W    ±1%  C(可以选用)       0
# 8    180KΩ   1/4W    ±1%  C(可以选用)  237894
# 9   27.4KΩ   1/4W    ±1%  C(可以选用)       0
# 10     2kΩ   1/4W    ±1%  C(可以选用)      28
# 11   510kΩ   1/4W    ±1%  C(可以选用)    2342
# 12   110kΩ   1/4W    ±1%  C(可以选用)    9825
# 13    82kΩ   1/4W    ±1%  C(可以选用)    4850
# 14    33kΩ   1/4W    ±1%  C(可以选用)       0
# 15    200k  43104    ±1%  B(推荐选用)   39736
# 16    499k  43104    ±1%  C(可以选用)       0
# 17     68k  43104    ±1%  B(推荐选用)   14283
# 18   3.6KΩ   1/4W    ±1%  C(可以选用)       0
# 19   2.7KΩ   1/4W    ±1%  C(可以选用)       0
# 20    15KΩ   1/4W    ±1%  C(可以选用)  181084
# 21     1kΩ   1/4W    ±1%  F(禁止使用)       0
# 22   430kΩ   1/4W    ±1%  C(可以选用)  269340
# 23   330kΩ   1/4W    ±1%  C(可以选用)       0
# 24    100k  43104    ±1%  B(推荐选用)  146431
# 25    36kΩ   1/4W   0.01  B(推荐选用)       0
# 26    22KΩ   1/4W    ±1%  B(推荐选用)   25552
# 27   1.2KΩ   1/4W    ±1%  B(推荐选用)    4748
# 28     1KΩ   1/4W    ±1%  B(推荐选用)   34639
# 29   240kΩ   1/4W    ±1%  C(可以选用)   59168
# ..     ...    ...    ...      ...     ...
# 45   330kΩ  1/10W    ±1%  C(可以选用)   16650
# 46   110kΩ   1/4W    ±1%  C(可以选用)    4650
# 47   5.1kΩ   1/4W    ±1%  B(推荐选用)   41634
# 48    301k  43104    ±1%  C(可以选用)       0
# 49    510k  43104    ±5%  C(可以选用)    4040
# 50     2kΩ   1/4W    ±1%  B(推荐选用)  173886
# 51   6.8KΩ   1/4W    ±5%  B(推荐选用)       0
# 52    18KΩ   1/4W    ±1%  B(推荐选用)       0
# 53    47KΩ   1/4W    ±1%  B(推荐选用)       0
# 54    33kΩ   1/4W    ±1%  C(可以选用)   84348
# 55    22kΩ   1/4W    ±5%  C(可以选用)    4676
# 56   274kΩ   1/4W    ±1%  C(可以选用)   11824
# 57     22k  43104    ±5%  C(可以选用)       0
# 58    2.4k  43104    ±5%  B(推荐选用)    4800
# 59   3.3kΩ   1/4W    ±5%  B(推荐选用)   12589
# 60    51KΩ   1/4W  ±0.1%  C(可以选用)       0
# 61    43kΩ   1/4W    ±1%  C(可以选用)   64213
# 62   120kΩ   1/4W    ±1%  C(可以选用)   24942
# 63   365kΩ   1/4W    ±1%  C(可以选用)  158998
# 64    33kΩ   1/4W    ±5%  C(可以选用)    8286
# 65    75kΩ   1/4W    ±1%  C(可以选用)    9650
# 66   100kΩ   1/4W    ±1%  C(可以选用)    9550
# 67    20kΩ   1/4W    ±1%  B(推荐选用)  109807
# 68   510kΩ   1/4W    ±1%  B(推荐选用)  459318
# 69    27KΩ   1/4W  ±0.1%  C(可以选用)       0
# 70   4.7KΩ   1/4W    ±1%  B(推荐选用)   11352
# 71   2.2KΩ   1/4W    ±1%  B(推荐选用)   10000
# 72   220kΩ   1/4W    ±1%  C(可以选用)   56702
# 73   6.8kΩ   1/4W    ±1%  C(可以选用)     -50
# 74    82kΩ   1/4W    ±1%  C(可以选用)    9800
#
#                                                     h
# 0   http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 1   http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 2   http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 3   http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 4   http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 5   http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 6   http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 7   http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 8   http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 9   http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 10  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 11  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 12  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 13  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 14  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 15  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 16  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 17  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 18  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 19  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 20  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 21  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 22  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 23  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 24  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 25  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 26  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 27  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 28  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 29  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# ..                                                ...
# 45  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 46  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 47  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 48  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 49  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 50  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 51  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 52  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 53  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 54  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 55  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 56  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 57  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 58  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 59  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 60  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 61  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 62  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 63  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 64  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 65  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 66  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 67  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 68  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 69  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 70  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 71  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 72  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 73  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
# 74  http://pdm.invt.com.cn/Windchill/servlet/TypeB...
#
# [75 rows x 10 columns]
